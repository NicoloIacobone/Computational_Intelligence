# %%
from game import HumanPlayer, Game
from main import RandomPlayer, ReinforcementPlayer
from utils import Utils

# %%
humanPlayer = HumanPlayer()
randomPlayer = RandomPlayer()
reinforcementPlayer = ReinforcementPlayer()
# reinforcementPlayer.load_policy("RL_vs_Rand_random_move_05_decreasing_50k_1")

# %%
game = Game()
game.play(reinforcementPlayer, humanPlayer)
# Out:
# ⬜️ ⬜️ ⬜️ ⬜️ ⬜️
# ⬜️ ⬜️ ⬜️ ⬜️ ⬜️
# ⬜️ ⬜️ ⬜️ ⬜️ ⬜️
# ⬜️ ⬜️ ⬜️ ⬜️ ⬜️
# ⬜️ ⬜️ ⬜️ ⬜️ ⬜️
#
# Winner:  0
# 0

# %%
print(game.trajectory_player_1)

# %%
env = Utils()
env.train(reinforcementPlayer, randomPlayer, lose_reward=0)
# Out:
#   7%|▋         | 72/1000 [00:00<00:03, 236.95it/s]
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# Winner:  0
# ...

# %%
env.test(reinforcementPlayer, randomPlayer)
# Out:
# 100%|██████████| 1000/1000 [00:06<00:00, 161.34it/s]
# Win rate player 1: 100.0%
# Lose rate player 1: 0.0%
# Draw rate: 0.0%
# Average trajectory size: 1.0
# ---------------------------------------------
