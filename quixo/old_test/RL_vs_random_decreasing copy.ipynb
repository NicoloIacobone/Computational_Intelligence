# %%
from utils import Utils
from main import ReinforcementPlayer, RandomPlayer

# %%
Rand_Player_2 = RandomPlayer()
environment = Utils()

# %%
RL_player_1 = ReinforcementPlayer()
RL_player_1.load_policy("RL_vs_Rand_random_move_03_decreasing_50k_1")

# %%
RL_player_1.set_random_move(0.035)
environment.train(RL_player_1, Rand_Player_2, 50_000, policy_name="RL_vs_Rand_random_move_03_decreasing_50k", plot=True, decreasing_exp_rate=True)
environment.test(RL_player_1, Rand_Player_2, policy_name="RL_vs_Rand_random_move_03_decreasing_50k")
environment.evaluate_player(RL_player_1, "RL_vs_Rand_random_move_03_decreasing_50k_1")
# Out:
# 100%|██████████| 500/500 [00:34<00:00, 14.43it/s]/s]
# 100%|██████████| 500/500 [00:36<00:00, 13.63it/s]/s]
# 100%|██████████| 500/500 [00:36<00:00, 13.65it/s]t/s]
# 100%|██████████| 500/500 [00:36<00:00, 13.83it/s]t/s]
# 100%|██████████| 500/500 [00:35<00:00, 14.17it/s]t/s]
# 100%|██████████| 500/500 [00:36<00:00, 13.87it/s]t/s]
# 100%|██████████| 500/500 [00:27<00:00, 18.06it/s]t/s]
# 100%|██████████| 500/500 [00:28<00:00, 17.39it/s]t/s]
# 100%|██████████| 500/500 [00:29<00:00, 16.76it/s]t/s]
# 100%|██████████| 500/500 [00:28<00:00, 17.66it/s]t/s]
# 100%|██████████| 50000/50000 [58:39<00:00, 14.21it/s]
# 100%|██████████| 1000/1000 [00:55<00:00, 17.92it/s]
# Win rate player 1: 68.7%
# Lose rate player 1: 30.4%
# Draw rate: 0.8999999999999999%
# Average trajectory size: 26.591
# ---------------------------------------------
# Entries: 3197522
# Policy size: 204.67 MB
