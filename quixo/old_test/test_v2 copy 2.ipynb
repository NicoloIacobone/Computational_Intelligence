# %%
from utils import Utils
from main import ReinforcementPlayer, RandomPlayer

# %%
RL_player_1 = ReinforcementPlayer()
RL_player_1.set_random_move(0.5)
Rand_Player_2 = RandomPlayer()
environment = Utils()

# %%
environment.train(RL_player_1, Rand_Player_2, 25_000, policy_name="RL_vs_Rand_random_move_05_decreasing_100k_new_trajectory_v2", plot=True, decreasing_exp_rate=True)
RL_player_1.set_random_move(0.17)
environment.train(RL_player_1, Rand_Player_2, 25_000, policy_name="RL_vs_Rand_random_move_05_decreasing_100k_new_trajectory_v2", plot=True, decreasing_exp_rate=True)
RL_player_1.set_random_move(0.06)
environment.train(RL_player_1, Rand_Player_2, 25_000, policy_name="RL_vs_Rand_random_move_05_decreasing_100k_new_trajectory_v2", plot=True, decreasing_exp_rate=True)
RL_player_1.set_random_move(0.02)
environment.train(RL_player_1, Rand_Player_2, 25_000, policy_name="RL_vs_Rand_random_move_05_decreasing_100k_new_trajectory_v2", plot=True, decreasing_exp_rate=True)
environment.test(RL_player_1, Rand_Player_2, policy_name="RL_vs_Rand_random_move_05_decreasing_100k_new_trajectory_v2")
environment.evaluate_player(RL_player_1, "RL_vs_Rand_random_move_05_decreasing_100k_new_trajectory_v2_1")
# Out:
# ...
# 100%|██████████| 1000/1000 [00:57<00:00, 17.36it/s]
# Win rate player 1: 54.2%
# Lose rate player 1: 43.7%
# Draw rate: 2.1%
# Average trajectory size: 15.826
# ---------------------------------------------
# Entries: 1245868
# Policy size: 79.75 MB
