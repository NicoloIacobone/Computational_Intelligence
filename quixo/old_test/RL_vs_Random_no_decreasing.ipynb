# %%
from utils import Utils
from main import ReinforcementPlayer, RandomPlayer

# %%
Rand_Player_2 = RandomPlayer()
environment = Utils()

# %%
RL_player_1 = ReinforcementPlayer()
RL_player_1.set_random_move(0.3)
environment.train(RL_player_1, Rand_Player_2, 50_000, policy_name="RL_vs_Rand_random_move_03_50k", plot=True)
environment.test(RL_player_1, Rand_Player_2, policy_name="RL_vs_Rand_random_move_03_50k")
environment.evaluate_player(RL_player_1, "RL_vs_Rand_random_move_03_50k_1")
# Out:
# ...
# 100%|██████████| 1000/1000 [01:03<00:00, 15.65it/s]
# Win rate player 1: 52.900000000000006%
# Lose rate player 1: 45.5%
# Draw rate: 1.6%
# Average trajectory size: 32.238
# ---------------------------------------------
# Entries: 1644050
# Policy size: 105.24 MB

# %%
RL_player_1 = ReinforcementPlayer()
RL_player_1.set_random_move(0.5)
environment.train(RL_player_1, Rand_Player_2, 50_000, policy_name="RL_vs_Rand_random_move_05_50k", plot=True)
environment.test(RL_player_1, Rand_Player_2, policy_name="RL_vs_Rand_random_move_05_50k")
environment.evaluate_player(RL_player_1, "RL_vs_Rand_random_move_05_50k_1")
# Out:
# ...
# 100%|██████████| 1000/1000 [01:24<00:00, 11.78it/s]
# Win rate player 1: 31.3%
# Lose rate player 1: 66.8%
# Draw rate: 1.9%
# Average trajectory size: 41.338
# ---------------------------------------------
# Entries: 1856515
# Policy size: 118.83 MB

# %%
RL_player_1 = ReinforcementPlayer()
RL_player_1.set_random_move(0.7)
environment.train(RL_player_1, Rand_Player_2, 50_000, policy_name="RL_vs_Rand_random_move_07_50k", plot=True)
environment.test(RL_player_1, Rand_Player_2, policy_name="RL_vs_Rand_random_move_07_50k")
environment.evaluate_player(RL_player_1, "RL_vs_Rand_random_move_07_50k_1")
# Out:
# ...
# 100%|██████████| 1000/1000 [01:35<00:00, 10.48it/s]
# Win rate player 1: 20.599999999999998%
# Lose rate player 1: 76.0%
# Draw rate: 3.4000000000000004%
# Average trajectory size: 44.886
# ---------------------------------------------
# Entries: 1910527
# Policy size: 122.28 MB
