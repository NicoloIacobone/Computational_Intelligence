# %%
from utils import Utils
from main import ReinforcementPlayer, RandomPlayer

# %%
RL_player_1 = ReinforcementPlayer()
RL_player_1.set_random_move(0.5)
Rand_Player_2 = RandomPlayer()
environment = Utils()

# %%
environment.train(RL_player_1, Rand_Player_2, 50_000, policy_name="RL_vs_Rand_random_move_05_decreasing_100k_new_trajectory", plot=True, decreasing_exp_rate=True)
RL_player_1.set_random_move(0.17)
environment.train(RL_player_1, Rand_Player_2, 50_000, policy_name="RL_vs_Rand_random_move_05_decreasing_100k_new_trajectory", plot=True, decreasing_exp_rate=True)
# Out:
# ...
# 100%|██████████| 50000/50000 [1:00:38<00:00, 13.74it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       2 RL_player_1.set_random_move(0.17)
#       3 environment.train(RL_player_1, Rand_Player_2, 50_000, policy_name="RL_vs_Rand_random_move_05_decreasing_100k_new_trajectory", plot=True, decreasing_exp_rate=True)
# ----> 4 environment.test(RL_player_1, Rand_Player_2, policy_name="RL_vs_Rand_random_move_05_decreasing_100k_new_rewards_1")
#       5 environment.evaluate_player(RL_player_1, "RL_vs_Rand_random_move_05_decreasing_100k_new_rewards_1_1")
#
# File ~/Desktop/nico/UNIVERSITA/MAGISTRALE/3_Semestre/Computational_Intelligence/Labs/My_Fork/Computational_Intelligence/quixo/utils.py:84, in Utils.test(self, player1, player2, games, policy_name, plot)
#      82     player1.set_random_move(0)
#      83     if not plot:
# ...

# %%
environment.test(RL_player_1, Rand_Player_2, policy_name="RL_vs_Rand_random_move_05_decreasing_100k_new_trajectory")
# Out:
# 100%|██████████| 1000/1000 [00:58<00:00, 16.99it/s]
# Win rate player 1: 55.2%
# Lose rate player 1: 43.5%
# Draw rate: 1.3%
# Average trajectory size: 15.84
# ---------------------------------------------
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 environment.test(RL_player_1, Rand_Player_2, policy_name="RL_vs_Rand_random_move_05_decreasing_100k_new_trajectory")
# ----> 2 environment.evaluate_player(RL_player_1, "RL_vs_Rand_random_move_05_decreasing_100k_new_rewards_1_1")
#
# File ~/Desktop/nico/UNIVERSITA/MAGISTRALE/3_Semestre/Computational_Intelligence/Labs/My_Fork/Computational_Intelligence/quixo/utils.py:117, in Utils.evaluate_player(self, player_to_evaluate, policy)
#     115 def evaluate_player(self, player_to_evaluate: ReinforcementPlayer, policy = None):
#     116     if policy is not None:
# ...

# %%
environment.evaluate_player(RL_player_1, "RL_vs_Rand_random_move_05_decreasing_100k_new_trajectory_1")
# Out:
# Entries: 1438277
# Policy size: 92.06 MB
