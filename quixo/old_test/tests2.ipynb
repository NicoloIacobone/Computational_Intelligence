# %%
from utils import Utils
from main import ReinforcementPlayer, RandomPlayer

# %%
environment = Utils()

# %%
RL_player_1 = ReinforcementPlayer()
Rand_Player_2 = RandomPlayer()

# %%
environment.train(RL_player_1, Rand_Player_2, plot=True)
# environment.test(RL_player_1, Rand_Player_2, policy_name="RL_vs_Rand_random_move_50k")
# Out:
# ...
# 100%|██████████| 1000/1000 [02:06<00:00,  7.93it/s]

# %%
environment.evaluate_player(RL_player_1, "RL_vs_Rand_random_move_50k_1")
# Out:
# Entries: 39300
# Policy size: 2.52 MB
