# %%
from utils import Utils
from main import ReinforcementPlayer, RandomPlayer

# %%
RL_player_1 = ReinforcementPlayer()
RL_player_1.set_random_move(0.5)
Rand_Player_2 = RandomPlayer()
environment = Utils()

# %%
environment.train(RL_player_1, Rand_Player_2, 100_000, 10, -10, "RL_vs_Rand_random_move_05_decreasing_100k_new_rewards_1", True, True)
environment.test(RL_player_1, Rand_Player_2, policy_name="RL_vs_Rand_random_move_05_decreasing_100k_new_rewards_1", plot=True)
environment.evaluate_player(RL_player_1, "RL_vs_Rand_random_move_05_decreasing_100k_new_rewards_1_1")
# Out:
# ...
# 100%|██████████| 1000/1000 [01:00<00:00, 16.60it/s]
# Entries: 1605503
# Policy size: 102.77 MB

# %%
environment.test(RL_player_1, Rand_Player_2, policy_name="RL_vs_Rand_random_move_05_decreasing_100k_new_rewards_1")
# Out:
# 100%|██████████| 1000/1000 [01:02<00:00, 15.94it/s]
# Win rate player 1: 51.2%
# Lose rate player 1: 47.5%
# Draw rate: 1.3%
# Average trajectory size: 16.212
# ---------------------------------------------

# %%
RL_player_1.create_policy("RL_vs_Rand_random_move_05_decreasing_100k_new_rewards_1_1")

# %%
environment.evaluate_player(RL_player_1, "RL_vs_Rand_random_move_05_decreasing_100k_new_rewards_1_1")
# Out:
# Entries: 1613740
# Policy size: 103.29 MB
