# %%
from utils import Utils
from main import ReinforcementPlayer, RandomPlayer

# %%
Rand_Player_2 = RandomPlayer()
environment = Utils()

# %%
RL_player_1 = ReinforcementPlayer()
RL_player_1.load_policy("RL_vs_Rand_random_move_07_decreasing_50k_1")

# %%
RL_player_1.set_random_move(0.24)
environment.train(RL_player_1, Rand_Player_2, 50_000, policy_name="RL_vs_Rand_random_move_07_decreasing_50k", plot=True, decreasing_exp_rate=True)
environment.test(RL_player_1, Rand_Player_2, policy_name="RL_vs_Rand_random_move_07_decreasing_50k")
environment.evaluate_player(RL_player_1, "RL_vs_Rand_random_move_07_decreasing_50k_1")
# Out:
# 100%|██████████| 500/500 [00:46<00:00, 10.69it/s]it/s]
# 100%|██████████| 500/500 [00:46<00:00, 10.74it/s]/s]
# 100%|██████████| 500/500 [00:37<00:00, 13.29it/s]t/s]
# 100%|██████████| 500/500 [00:31<00:00, 15.71it/s]t/s]
# 100%|██████████| 500/500 [00:31<00:00, 15.78it/s]t/s]
# 100%|██████████| 500/500 [00:30<00:00, 16.33it/s]t/s]
# 100%|██████████| 500/500 [00:29<00:00, 16.81it/s]t/s]
# 100%|██████████| 500/500 [00:27<00:00, 17.88it/s]t/s]
# 100%|██████████| 500/500 [00:28<00:00, 17.66it/s]t/s]
# 100%|██████████| 500/500 [00:26<00:00, 18.96it/s]9it/s]
# 100%|██████████| 50000/50000 [1:01:21<00:00, 13.58it/s]
# 100%|██████████| 1000/1000 [00:55<00:00, 18.10it/s]
# Win rate player 1: 59.099999999999994%
# Lose rate player 1: 39.6%
# Draw rate: 1.3%
# Average trajectory size: 29.136
# ---------------------------------------------
# Entries: 3067759
# Policy size: 196.36 MB
