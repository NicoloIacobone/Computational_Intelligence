# %%
from utils import Utils
from main import ReinforcementPlayer, RandomPlayer

# %%
Rand_Player_2 = RandomPlayer()
environment = Utils()

# %%
RL_player_1 = ReinforcementPlayer()
RL_player_1.set_random_move(0.3)
environment.train(RL_player_1, Rand_Player_2, 50_000, policy_name="RL_vs_Rand_random_move_03_decreasing_50k", plot=True, decreasing_exp_rate=True)
environment.test(RL_player_1, Rand_Player_2, policy_name="RL_vs_Rand_random_move_03_decreasing_50k")
environment.evaluate_player(RL_player_1, "RL_vs_Rand_random_move_03_decreasing_50k_1")
# Out:
# ...
# 100%|██████████| 1000/1000 [01:13<00:00, 13.65it/s]
# Win rate player 1: 42.8%
# Lose rate player 1: 54.800000000000004%
# Draw rate: 2.4%
# Average trajectory size: 38.354
# ---------------------------------------------
# Entries: 1629991
# Policy size: 104.33 MB

# %%
RL_player_1 = ReinforcementPlayer()
RL_player_1.set_random_move(0.5)
environment.train(RL_player_1, Rand_Player_2, 50_000, policy_name="RL_vs_Rand_random_move_05_decreasing_50k", plot=True, decreasing_exp_rate=True)
environment.test(RL_player_1, Rand_Player_2, policy_name="RL_vs_Rand_random_move_05_decreasing_50k")
environment.evaluate_player(RL_player_1, "RL_vs_Rand_random_move_05_decreasing_50k_1")
# Out:
# ...
# 100%|██████████| 1000/1000 [01:32<00:00, 10.77it/s]
# Win rate player 1: 45.2%
# Lose rate player 1: 52.0%
# Draw rate: 2.8000000000000003%
# Average trajectory size: 37.366
# ---------------------------------------------
# Entries: 1754504
# Policy size: 112.30 MB

# %%
RL_player_1 = ReinforcementPlayer()
RL_player_1.set_random_move(0.7)
environment.train(RL_player_1, Rand_Player_2, 50_000, policy_name="RL_vs_Rand_random_move_07_decreasing_50k", plot=True, decreasing_exp_rate=True)
environment.test(RL_player_1, Rand_Player_2, policy_name="RL_vs_Rand_random_move_07_decreasing_50k")
environment.evaluate_player(RL_player_1, "RL_vs_Rand_random_move_07_decreasing_50k_1")
# Out:
# ...
# 100%|██████████| 1000/1000 [01:35<00:00, 10.45it/s]
# Win rate player 1: 25.5%
# Lose rate player 1: 72.39999999999999%
# Draw rate: 2.1%
# Average trajectory size: 42.818
# ---------------------------------------------
# Entries: 1837809
# Policy size: 117.63 MB
